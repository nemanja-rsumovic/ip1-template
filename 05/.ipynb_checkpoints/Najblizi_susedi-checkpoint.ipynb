# %% [markdown]
# # KNearestNeighbors 🦆
#
# > If it looks like a duck, swims like a duck, and quacks like a duck, then it probably is a duck.

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Klasifikacija karcinoma
#
# Koristimo skup podataka [Breast Cancer Wisconsin (Diagnostic) Data Set](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)).
# Skup podataka se sastoji od 33 atributa. Vrednosti atributa su izračunati sa digitalizovanih slika mase, koje opisuju karakteristike ćelija prikazanih na slici. Vrednost atributa **diagnosis** sadrži informaciju o tome da li je u pitanju benigni ili maligni tumor.

# %% [markdown]
# ## Učitavanje i analiza skupa podataka

# %%
data = pd.read_csv('data.csv')
data.columns # nazivi atributa
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Rad sa nedostajućim vrednostima
# U skupu postoje nedostajuće vrednosti. Detaljnijom proverom po kolonama, vidimo da se one javljaju samo u koloni _Unnamed: 32_, kao i da su zapravo sve vrednosti u ovoj koloni NaN. Iz tog razloga smatramo da je ovo greška i kolonu izbacujemo iz skupa.

# %%
data.isna().any().any() # da li u skupu postoje nedostajuće vrednosti
# Out:
# True

# %%
data.isna().any() # u kojim kolonama se javljaju nedostajuće vrednosti
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# concavity_worst            False
# concave points_worst       False
# symmetry_worst             False
# fractal_dimension_worst    False
# Unnamed: 32                 True
# dtype: bool

# %%
data['Unnamed: 32'].isna().all() # Sve vrednosti u koloni 'Unnamed: 32' su NaN
# Out:
# True

# %%
data.drop('Unnamed: 32', axis=1, inplace=True) # izbacujemo kolonu 'Unnamed: 32' iz skupa

# %% [raw]
# Takođe možemo primetiti da kolona _id_ ne sadrži informaciju o karakterisitikama ćelije koju klasifikujemo, pa je i nju potrebno izbaciti iz skupa podataka.

# %%
data.drop('id', axis=1, inplace=True)

# %% [markdown]
# ### Podela na ulazne i ciljne atribute
# Informacija o vrsti tumora se nalazi u koloni _diagnosis_ (ciljni atribut), dok se ostali atributi koriste za predikciju (ulazni atributi).

# %%
Y = data['diagnosis']
X = data.drop('diagnosis', axis=1)
feature_names = X.columns
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
Y.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# Vrednosti u Y (klasa) je M - maligni i B - benigni tumor. Dakle, rešavamo problem _binarne klasifikacije_.

# %% [markdown]
# ### Provera balansiranosti klasa
#
# Na osnovu histograma vidimo da se u skupu podataka nalazi 212 instanci malignog i 357 instanci benignog tumora.
# Primećujemo blagu nebalansiranost (38%-62%).
#
# _NAPOMENA_: Na narednim časovima ćemo pokazati metode rada sa nebalansiranim klasama.

# %%
import numpy as np

freq, bins, _ = plt.hist(Y, edgecolor='white', bins=2)
print(freq)
print(bins)

bin_centers = np.diff(bins)*0.5 + bins[:-1] # računanje centra korpice
print(bin_centers)

for fr, x in zip(freq, bin_centers):
    height = int(fr)
    plt.annotate("{}".format(height),
               xy = (x, height),             # poziciranje broja iznad korpice
               xytext = (0,0.2),             # odvajanje teksta od korpice
               textcoords = "offset points", 
               ha = 'center', va = 'bottom'
               )

plt.show()
# Out:
# [212. 357.]
# [0.  0.5 1. ]
# [0.25 0.75]

# %% [markdown]
# Tipično, binarna klasifikacija sadrži jednu klasu koja predstavlja _normalno stanje_ i drugu koja predstavlja _abnormalno stanje_.
# U našem primeru, benigni tumor predstavlja normalno stanje, a maligni abnormalno.
# Klasi koja predstavlja normalno stanje se dodeljuje oznaka **0**, dok se drugoj klasi dodeljuje oznaka **1**.

# %%
Y.replace("B", 0, inplace=True)
Y.replace("M", 1, inplace=True)

# %% [markdown]
# ### Analiza ulaznih atributa
#
# Na osnovu statistika kolona možemo primetiti da se vrednosti nalaze u različitim rasponima.
#
# Pitanja na koja bi trebalo da odogovorimo su:
#
# **1.** <u>Da li je potrebno izvršiti normalizaciju prilikom korišćenja KNN? (Da, zašto?)</u>
#
#     Da, normalizacija je obično potrebna prilikom korišćenja KNN (k-najbližih suseda). KNN algoritam koristi udaljenost između tačaka kako bi odredio koje tačke su slične. Ako su karakteristike različitih skala ili opsega, udaljenosti mogu biti dominirane od strane karakteristika sa većim vrednostima, što može dovesti do netačnih rezultata. Na primer, ako imate karakteristike koje mere visinu u metrima i težinu u kilogramima, visina može dominirati udaljenostima zbog većih vrednosti u metrima. Normalizacija (ili standardizacija) reskalira karakteristike na sličan opseg, čime se osigurava da su svi atributi podataka podjednako važni prilikom izračunavanja udaljenosti.
#
# **2.** <u>Da li je KNN robusan na autlajere? (Ne, zašto?)</u>
#
#     Ne, KNN nije robusan na autlajere. KNN algoritam pridružuje novu instancu klasifikacionom modelu na osnovu njenih najbližih suseda. Međutim, autlajeri mogu značajno uticati na ovaj postupak, jer mogu biti daleko od većine podataka i značajno promeniti procene o klasi novog podatka. Na primer, ako imate mali skup podataka i jedan autlajer koji je daleko od većine tačaka, KNN može pogrešno klasifikovati novu instancu pridruživanjem klase koja je dominantna među njegovim autlajerima. Zbog toga se preporučuje da se pre primene KNN algoritma na skup podataka obradi autlajere ili koristi drugi algoritam koji je manje osetljiv na njih.

# %% [markdown]
# ### Rad sa elementima van granica
#
# Pošto želimo da noramlizujemo podatke na raspon [0, 1], prvo je potrebno proveriti da li postoje elementi van granica, i kako bi oni uticali na normalizaciju naših podataka (Pogledajte svesku o normalizaciji).
# Takođe, KNN je osetljiv na elemente van granica, što predstavlja još jedan motiv provere.

# %% [markdown]
# #### Provera da li u skupu postoje elementi van granica
#
# Postoji veliki broj metoda za detekciju elemenata van granica:
# * Boxplot
# * Histogram
# * Mean and Standard Deviation
# * IQR (Inter Quartile Range)
# * Z-score
# * Percentile
#
# U ovom zadatku ćemo iskoristiti IQR. Za domaći istražite ostale metode.

# %% [markdown]
# IQR računa interkvartlano rastojanje. Kao povratnu vrednost čuvamo broj autlajera koji su manji od donje granice ili veći, kao i procenat podataka po kolonama koji su van granica.

# %%
def IQR(data, feature_names):
    
    iqr = pd.DataFrame(0, index=feature_names, columns=['lower', 'min', 'num_lower', 'upper', 'max', 'num_upper', 'percantage'])
    for name in feature_names:

        (Q1, Q3) = X[name].quantile([0.25, 0.75])
        IQR = Q3 - Q1
        upper = Q3 + (1.5 * IQR)
        lower = Q1 - (1.5 * IQR)
        
        iqr.loc[name, 'upper'] = upper
        iqr.loc[name, 'lower'] = lower

        num_of_out_lower = (X[name] < lower).sum()
        num_of_out_upper = (X[name] > upper).sum()

        percentage = round((num_of_out_lower + num_of_out_upper) / X.shape[0] * 100)

        iqr.loc[name, 'num_lower'], iqr.loc[name, 'num_upper'], iqr.loc[name, 'percantage']  = num_of_out_lower, num_of_out_upper, percentage
        iqr.loc[name, 'min'], iqr.loc[name, 'max'] = min(X[name]), max(X[name])    
    return iqr

# %% [markdown]
# ❓ _Pitanje_:  Da li proveru elemenata van granica i normalizaciju vršimo pre podele na trening i test skup?
#
# **Nakon, inače smo kompromitovali test skup.**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, stratify=Y, random_state=41)

# %%
IQR(X_train, feature_names)
# Out:
# C:\Users\Nemanja\AppData\Local\Temp\ipykernel_3712\141387001.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '21.9' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   iqr.loc[name, 'upper'] = upper
# C:\Users\Nemanja\AppData\Local\Temp\ipykernel_3712\141387001.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '5.579999999999999' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   iqr.loc[name, 'lower'] = lower
# C:\Users\Nemanja\AppData\Local\Temp\ipykernel_3712\141387001.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.981' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   iqr.loc[name, 'min'], iqr.loc[name, 'max'] = min(X[name]), max(X[name])
# C:\Users\Nemanja\AppData\Local\Temp\ipykernel_3712\141387001.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '28.11' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   iqr.loc[name, 'min'], iqr.loc[name, 'max'] = min(X[name]), max(X[name])
#                               lower         min  num_lower        upper  \
# radius_mean                5.580000    6.981000          0    21.900000
# texture_mean               7.725000    9.710000          0    30.245000
# perimeter_mean            31.775000   43.790000          0   147.495000
# area_mean               -123.300000  143.500000          0  1326.300000
# smoothness_mean            0.057975    0.052630          1     0.133695
# compactness_mean          -0.033300    0.019380          0     0.228620
# concavity_mean            -0.122150    0.000000          0     0.282410
# concave points_mean       -0.060225    0.000000          0     0.154535
# symmetry_mean              0.111200    0.106000          1     0.246400
# fractal_dimension_mean     0.045070    0.049960          0     0.078750
# radius_se                 -0.137350    0.111500          0     0.848650
# texture_se                -0.126250    0.360200          0     2.434150
# perimeter_se              -1.020500    0.757000          0     5.983500
# area_se                  -23.160000    6.802000          0    86.200000
# smoothness_se              0.000703    0.001713          0     0.012612
# compactness_se            -0.015975    0.002252          0     0.061505
# concavity_se              -0.025350    0.000000          0     0.082490
# concave points_se         -0.002970    0.000000          0     0.025318
# symmetry_se                0.002680    0.007882          0     0.035960
# fractal_dimension_se      -0.001217    0.000895          0     0.008023
# radius_worst               4.340000    7.930000          0    27.460000
# texture_worst              8.120000   12.020000          0    42.680000
# perimeter_worst           22.175000   50.410000          0   187.335000
# area_worst              -337.750000  185.200000          0  1937.050000
# smoothness_worst           0.072500    0.071170          1     0.190100
# compactness_worst         -0.140650    0.027290          0     0.626950
# concavity_worst           -0.288100    0.000000          0     0.785500
# concave points_worst      -0.079775    0.000000          0     0.306105
# symmetry_worst             0.149150    0.156500          0     0.419150
# fractal_dimension_worst    0.040530    0.055040          0     0.123010
#
#                                 max  num_upper  percantage
# radius_mean                28.11000         14           2
# texture_mean               39.28000          7           1
# perimeter_mean            188.50000         13           2
# area_mean                2501.00000         25           4
# smoothness_mean             0.16340          5           1
# compactness_mean            0.34540         16           3
# concavity_mean              0.42680         18           3
# concave points_mean         0.20120         10           2
# symmetry_mean               0.30400         14           3
# fractal_dimension_mean      0.09744         15           3
# radius_se                   2.87300         38           7
# texture_se                  4.88500         20           4
# perimeter_se               21.98000         38           7
# area_se                   542.20000         65          11
# smoothness_se               0.03113         30           5
# compactness_se              0.13540         28           5
# concavity_se                0.39600         22           4
# concave points_se           0.05279         19           3
# symmetry_se                 0.07895         27           5
# fractal_dimension_se        0.02984         28           5
# radius_worst               36.04000         17           3
# texture_worst              49.54000          5           1
# perimeter_worst           251.20000         15           3
# area_worst               4254.00000         35           6
# smoothness_worst            0.22260          6           1
# compactness_worst           1.05800         16           3
# concavity_worst             1.25200         12           2
# concave points_worst        0.29100          0           0
# symmetry_worst              0.66380         23           4
# fractal_dimension_worst     0.20750         24           4

# %% [markdown]
# Dakle, možemo zaključiti da postoje autlajeri, ali ih neam mnogo i vrednosti ne odskaču previše.

# %% [markdown]
# #### Metode za rad sa autlajerima
#
# Ukoliko smatramo da će autlajeri previše uticati na model možemo primeniti više tehnika:
# * Uklanjanje autlajera
# * Odsecanje - svi autlajeri se slikaju u granične vrednosti
# * Postavljanje na NaN + primena neke metode za rad sa nedostajućim vrednostima

# %% [markdown]
# 🤔 **_DOMAĆI_**: Primenite neku od ovih tehnika i uporedite sa modelom koji se dobija kada se originalne vrednosti autlajera ne menjaju:
#  - Koja od tehnika Vam se čini najbolja?
#  - Sa obzirom na to da nema mnogo autlajera, čini se da bi sve tehnike mogle da budu odgovarajuće.
#  - Pošto radimo sa atributima veličina, prečnik, simetrija itd. mase za koju se vrši klasifikacija u benigni/maligni karcinom, možda baš ekstremne vrednosti signaliziraju postojanje maligniteta?

# %% [markdown]
# #### Normalizacija
# Za normalizaciju ćemo iskoristiti MinMaxScaler
# Vrednosti min i max ćemo odrediti na osnovu trening skupa, a zatim primeniti transformaciju na test i trening skup.
# Ponovo naglašavamo, **neophodno je da podelu na test i trening izvršimo pre normalizacije!**
#
# 1. <u>Prevencija curenja informacija</u>: Ako primenite normalizaciju na celokupan skup podataka pre deljenja na trening i test skup, podaci iz test skupa će "cureti" u trening skup, što može dovesti do preprilagodjavanja. Normalizacija se vrši na osnovu statističkih karakteristika trening skupa (npr. srednja vrednost i standardna devijacija). Ako se ove statistike računaju koristeći i trening i test skup zajedno, informacije iz test skupa su dostupne prilikom računanja tih statistika, što može dovesti do preoptimizacije modela za test skup i netačnih procena performansi.
# 2. <u>
# Reprezentativnost test skup</u>a: Test skup treba da bude nezavisan uzorak podataka koji se koristi za procenu performansi modela. Ako normalizujete čitav skup podataka pre deljenja, to može dovesti do toga da test skup ne reprezentuje stvarnu raspodelu podataka u kojoj će se model primenjivati.
# 3. <u>
# Realističnost evaluacije performan</u>si: Normalizacija trening skupa, a zatim primena istih transformacija na test skupu, osigurava realističnu evaluaciju performansi modela. Model će se koristiti za predviđanje na neobrađenim podacima, tako da je važno da evaluacija modela bude bazirana na testiranju na podacima koji nisu bili dostupni tokom obuke.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Pomoćne funkcije
# Pošto ćemo trenirate više modela, pravimo pomoćne funkcije za pisanje izveštaja.

# %%
# !pip install termcolor
from sklearn.metrics import classification_report
from termcolor import colored

def report(model, x, y, text = "training"):
    y_pred = model.predict(x)
    
    print(colored("Classification report for model {} on {} data".format(type(model).__name__, text), "green"))
    print("---------------------------------------------------------------------------------")
    print(classification_report(y, y_pred, zero_division=True))
    print("---------------------------------------------------------------------------------")
    
    print(colored("Confusion matrix for model {} on {} data ".format(type(model).__name__, text), "green"))
    print("---------------------------------------------------------------------------------")
    print(pd.DataFrame(confusion_matrix(y, y_pred), columns=['B', 'M'], index=['B', 'M']))
    print("---------------------------------------------------------------------------------")

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier()

# %%
knn.fit(X_train, Y_train) # treninranje modela
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Model na trening skupu ima tačnost **0.98**.

# %%
Y_test_pred = knn.predict(X_test)
confusion_matrix(Y_test,Y_test_pred)
# Out:
# array([[89,  1],
#        [ 3, 50]], dtype=int64)

# %%
report(knn, X_train, Y_train)
# Out:
# Classification report for model KNeighborsClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       267
#            1       0.99      0.96      0.97       159
#
#     accuracy                           0.98       426
#    macro avg       0.98      0.98      0.98       426
# weighted avg       0.98      0.98      0.98       426
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model KNeighborsClassifier on training data
# ---------------------------------------------------------------------------------
#      B    M
# B  266    1
# M    7  152
# ---------------------------------------------------------------------------------

# %% [markdown]
# Izveštaj klasifikacije nad test skupom nam daje informaciju da je tačnost na test skupu **0,97**.
#
# _Pitanje1_: Da li je došlo do preprilagođavanja?
#
# _Pitanje2_: Koju vrstu grešaka u klasifikaciji želimo da minimizujemo? (Da li nam je bitnije da je FP ili FN malo?)

# %%
report(knn, X_test, Y_test, "test")
# Out:
# Classification report for model KNeighborsClassifier on test data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        90
#            1       0.98      0.94      0.96        53
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model KNeighborsClassifier on test data
# ---------------------------------------------------------------------------------
#     B   M
# B  89   1
# M   3  50
# ---------------------------------------------------------------------------------

# %% [markdown]
# Trenutni model, iako ima visoku preciznost, pravi veći broj grešaka prvog reda, i zato ćemo pokušati da ga unapredimo, promenom hiper-parametara.

# %% [markdown]
# ## Podešavanje hiper-parametara modela
#
# Hiper-paramtri su parametri koji se ne uče tokom treniranja. U scikit-learn biblioteci, hiper parametri se prosleđuju kao argumenti konstrukoru.
#
# Želimo da promenimo hiper-parametre našeg modela, ali ne znamo koja kombinacija parametara će nam dati najbolji model.

# %% [markdown]
# ### GridSearchCV

# %% [markdown]
# U mapi čuvamo informaciju o imenima i vrednostima parametara koje želimo da ispitamo.

# %%
from sklearn.model_selection import GridSearchCV

params = {'criterion': ['gini', 'entropy'],
          'max_depth': [2,4,6,8]
         }
params_grid = {'n_neighbors': range(10, 50, 5),
               'weights': ['uniform', 'distance'],
                'p': [1, 2]}

#estimator = GridSearchCV(KNeighborsClassifier(), params_grid, cv=6)
estimator = GridSearchCV(KNeighborsClassifier(), params_grid, cv=6, verbose=4)

# %%
estimator.fit(X_train, Y_train)
# Out:
# Fitting 6 folds for each of 32 candidates, totalling 192 fits
# [CV 1/6] END n_neighbors=10, p=1, weights=uniform;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=10, p=1, weights=uniform;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=10, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 4/6] END n_neighbors=10, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=10, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=10, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=10, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=10, p=1, weights=distance;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=10, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 4/6] END n_neighbors=10, p=1, weights=distance;, score=0.944 total time=   0.0s
# [CV 5/6] END n_neighbors=10, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=10, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=10, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=10, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=10, p=2, weights=uniform;, score=0.944 total time=   0.0s
# [CV 4/6] END n_neighbors=10, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 5/6] END n_neighbors=10, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=10, p=2, weights=uniform;, score=0.958 total time=   0.0s
# [CV 1/6] END n_neighbors=10, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 2/6] END n_neighbors=10, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=10, p=2, weights=distance;, score=0.958 total time=   0.0s
# [CV 4/6] END n_neighbors=10, p=2, weights=distance;, score=0.944 total time=   0.0s
# [CV 5/6] END n_neighbors=10, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=10, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 1/6] END n_neighbors=15, p=1, weights=uniform;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=15, p=1, weights=uniform;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=15, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 4/6] END n_neighbors=15, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=15, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=15, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=15, p=1, weights=distance;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=15, p=1, weights=distance;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=15, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 4/6] END n_neighbors=15, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 5/6] END n_neighbors=15, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=15, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=15, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=15, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=15, p=2, weights=uniform;, score=0.944 total time=   0.0s
# [CV 4/6] END n_neighbors=15, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 5/6] END n_neighbors=15, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=15, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 1/6] END n_neighbors=15, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=15, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=15, p=2, weights=distance;, score=0.944 total time=   0.0s
# [CV 4/6] END n_neighbors=15, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 5/6] END n_neighbors=15, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=15, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 1/6] END n_neighbors=20, p=1, weights=uniform;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=20, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=20, p=1, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=20, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=20, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=20, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=20, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=20, p=1, weights=distance;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=20, p=1, weights=distance;, score=0.915 total time=   0.0s
# [CV 4/6] END n_neighbors=20, p=1, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=20, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=20, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=20, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=20, p=2, weights=uniform;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=20, p=2, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=20, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 5/6] END n_neighbors=20, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=20, p=2, weights=uniform;, score=0.958 total time=   0.0s
# [CV 1/6] END n_neighbors=20, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=20, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 3/6] END n_neighbors=20, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 4/6] END n_neighbors=20, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 5/6] END n_neighbors=20, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=20, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=25, p=1, weights=uniform;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=25, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=25, p=1, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=25, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=25, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=25, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=25, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=25, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=25, p=1, weights=distance;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=25, p=1, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=25, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=25, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=25, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=25, p=2, weights=uniform;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=25, p=2, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=25, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 5/6] END n_neighbors=25, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=25, p=2, weights=uniform;, score=0.958 total time=   0.0s
# [CV 1/6] END n_neighbors=25, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=25, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=25, p=2, weights=distance;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=25, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 5/6] END n_neighbors=25, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=25, p=2, weights=distance;, score=0.958 total time=   0.0s
# [CV 1/6] END n_neighbors=30, p=1, weights=uniform;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=30, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=30, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 4/6] END n_neighbors=30, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=30, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=30, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=30, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=30, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=30, p=1, weights=distance;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=30, p=1, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=30, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=30, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=30, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=30, p=2, weights=uniform;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=30, p=2, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=30, p=2, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=30, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=30, p=2, weights=uniform;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=30, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=30, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=30, p=2, weights=distance;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=30, p=2, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=30, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=30, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=35, p=1, weights=uniform;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=35, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=35, p=1, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=35, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=35, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=35, p=1, weights=uniform;, score=0.958 total time=   0.0s
# [CV 1/6] END n_neighbors=35, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=35, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=35, p=1, weights=distance;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=35, p=1, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=35, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=35, p=1, weights=distance;, score=0.958 total time=   0.0s
# [CV 1/6] END n_neighbors=35, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=35, p=2, weights=uniform;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=35, p=2, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=35, p=2, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=35, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=35, p=2, weights=uniform;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=35, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=35, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=35, p=2, weights=distance;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=35, p=2, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=35, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=35, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=40, p=1, weights=uniform;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=40, p=1, weights=uniform;, score=0.958 total time=   0.0s
# [CV 3/6] END n_neighbors=40, p=1, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=40, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=40, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=40, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=40, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=40, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=40, p=1, weights=distance;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=40, p=1, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=40, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=40, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=40, p=2, weights=uniform;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=40, p=2, weights=uniform;, score=0.958 total time=   0.0s
# [CV 3/6] END n_neighbors=40, p=2, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=40, p=2, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=40, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=40, p=2, weights=uniform;, score=0.958 total time=   0.0s
# [CV 1/6] END n_neighbors=40, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=40, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=40, p=2, weights=distance;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=40, p=2, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=40, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=40, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=45, p=1, weights=uniform;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=45, p=1, weights=uniform;, score=0.958 total time=   0.0s
# [CV 3/6] END n_neighbors=45, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 4/6] END n_neighbors=45, p=1, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=45, p=1, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=45, p=1, weights=uniform;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=45, p=1, weights=distance;, score=1.000 total time=   0.0s
# [CV 2/6] END n_neighbors=45, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=45, p=1, weights=distance;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=45, p=1, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=45, p=1, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=45, p=1, weights=distance;, score=0.972 total time=   0.0s
# [CV 1/6] END n_neighbors=45, p=2, weights=uniform;, score=0.972 total time=   0.0s
# [CV 2/6] END n_neighbors=45, p=2, weights=uniform;, score=0.958 total time=   0.0s
# [CV 3/6] END n_neighbors=45, p=2, weights=uniform;, score=0.901 total time=   0.0s
# [CV 4/6] END n_neighbors=45, p=2, weights=uniform;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=45, p=2, weights=uniform;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=45, p=2, weights=uniform;, score=0.958 total time=   0.0s
# [CV 1/6] END n_neighbors=45, p=2, weights=distance;, score=0.986 total time=   0.0s
# [CV 2/6] END n_neighbors=45, p=2, weights=distance;, score=0.972 total time=   0.0s
# [CV 3/6] END n_neighbors=45, p=2, weights=distance;, score=0.887 total time=   0.0s
# [CV 4/6] END n_neighbors=45, p=2, weights=distance;, score=0.915 total time=   0.0s
# [CV 5/6] END n_neighbors=45, p=2, weights=distance;, score=0.930 total time=   0.0s
# [CV 6/6] END n_neighbors=45, p=2, weights=distance;, score=0.958 total time=   0.0s
# GridSearchCV(cv=6, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(10, 50, 5), 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              verbose=4)

# %% [markdown]
# Možemo pogledati koja je najbolja kombinacija parametara

# %%
estimator.best_params_
# Out:
# {'n_neighbors': 10, 'p': 2, 'weights': 'distance'}

# %% [markdown]
# Kao i najbolji score

# %%
estimator.best_score_
# Out:
# 0.9624413145539906

# %%
report(estimator.best_estimator_, X_train, Y_train)
# Out:
# Classification report for model KNeighborsClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       267
#            1       1.00      1.00      1.00       159
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model KNeighborsClassifier on training data
# ---------------------------------------------------------------------------------
#      B    M
# B  267    0
# M    0  159
# ---------------------------------------------------------------------------------

# %%
report(estimator.best_estimator_, X_test, Y_test, "test")
# Out:
# Classification report for model KNeighborsClassifier on test data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        90
#            1       1.00      0.96      0.98        53
#
#     accuracy                           0.99       143
#    macro avg       0.99      0.98      0.98       143
# weighted avg       0.99      0.99      0.99       143
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model KNeighborsClassifier on test data
# ---------------------------------------------------------------------------------
#     B   M
# B  90   0
# M   2  51
# ---------------------------------------------------------------------------------

# %% [markdown]
# Takođe, možemo detaljnije pogledati i rezultate cross validacije.

# %%
estimator.cv_results_
# Out:
# {'mean_fit_time': array([0.00538321, 0.00284123, 0.0024581 , 0.00111119, 0.00206673,
#         0.00154245, 0.00223247, 0.0026447 , 0.00085378, 0.00228457,
#         0.00160893, 0.00160094, 0.00166476, 0.001212  , 0.00408057,
#         0.00276764, 0.00124896, 0.00206014, 0.00333464, 0.00199986,
#         0.00075928, 0.00220247, 0.00307035, 0.00119098, 0.00142841,
#         0.00089792, 0.00282645, 0.00158894, 0.0010825 , 0.00222099,
#         0.00142407, 0.00116022]),
#  'std_fit_time': array([0.00298125, 0.0034702 , 0.00267364, 0.00161922, 0.00317658,
#         0.00219241, 0.00301563, 0.00323089, 0.00129381, 0.00256701,
#         0.00238144, 0.00173699, 0.00350072, 0.00271012, 0.00335535,
#         0.00351474, 0.00124951, 0.00240275, 0.00397379, 0.00225647,
#         0.00169781, 0.00297817, 0.00238727, 0.00173698, 0.00233815,
#         0.00200782, 0.00302472, 0.00230125, 0.00153098, 0.00295975,
#         0.00294962, 0.00161094]),
#  'mean_score_time': array([0.00233249, 0.00961204, 0.00922187, 0.01039358, 0.00410938,
#         0.00951147, 0.008582  , 0.00829605, 0.00563073, 0.00954445,
#         0.00745972, 0.00988821, 0.00426877, 0.01152054, 0.00468032,
#         0.00842146, 0.00538977, 0.00884636, 0.00828453, 0.01003182,
#         0.00578928, 0.00828195, 0.00841788, 0.01006901, 0.00414745,
#         0.01111968, 0.0079668 , 0.00704594, 0.003956  , 0.01010072,
#         0.00982181, 0.00949248]),
#  'std_score_time': array([0.00255683, 0.00303899, 0.0014533 , 0.00307569, 0.00290917,
#         0.00221365, 0.002253  , 0.00066183, 0.00283197, 0.00159883,
#         0.00157555, 0.00224446, 0.00373925, 0.00194154, 0.00344782,
#         0.00149507, 0.0029048 , 0.00139388, 0.00168046, 0.00171285,
#         0.00316823, 0.00079677, 0.0024542 , 0.00301245, 0.00376163,
#         0.00268796, 0.00179613, 0.00251135, 0.00357031, 0.00181103,
#         0.00222729, 0.0014783 ]),
#  'param_n_neighbors': masked_array(data=[10, 10, 10, 10, 15, 15, 15, 15, 20, 20, 20, 20, 25, 25,
#                     25, 25, 30, 30, 30, 30, 35, 35, 35, 35, 40, 40, 40, 40,
#                     45, 45, 45, 45],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_p': masked_array(data=[1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1,
#                     2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_weights': masked_array(data=['uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_neighbors': 10, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 10, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 10, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 10, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 15, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 15, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 15, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 20, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 20, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 20, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 20, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 25, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 25, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 25, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 25, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 30, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 30, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 30, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 30, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 35, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 35, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 35, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 35, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 40, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 40, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 40, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 40, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 45, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 45, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 45, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 45, 'p': 2, 'weights': 'distance'}],
#  'split0_test_score': array([1.        , 1.        , 0.98591549, 0.97183099, 0.98591549,
#         0.98591549, 0.98591549, 0.98591549, 1.        , 1.        ,
#         0.98591549, 0.98591549, 1.        , 1.        , 0.98591549,
#         0.98591549, 1.        , 1.        , 0.98591549, 0.98591549,
#         1.        , 1.        , 0.98591549, 0.98591549, 1.        ,
#         1.        , 0.98591549, 0.98591549, 1.        , 1.        ,
#         0.97183099, 0.98591549]),
#  'split1_test_score': array([0.98591549, 0.98591549, 0.98591549, 0.98591549, 0.98591549,
#         0.98591549, 0.98591549, 0.98591549, 0.97183099, 0.98591549,
#         0.97183099, 0.98591549, 0.97183099, 0.97183099, 0.97183099,
#         0.97183099, 0.97183099, 0.97183099, 0.97183099, 0.97183099,
#         0.97183099, 0.97183099, 0.97183099, 0.97183099, 0.95774648,
#         0.97183099, 0.95774648, 0.97183099, 0.95774648, 0.97183099,
#         0.95774648, 0.97183099]),
#  'split2_test_score': array([0.91549296, 0.92957746, 0.94366197, 0.95774648, 0.91549296,
#         0.92957746, 0.94366197, 0.94366197, 0.90140845, 0.91549296,
#         0.90140845, 0.92957746, 0.90140845, 0.90140845, 0.90140845,
#         0.90140845, 0.91549296, 0.90140845, 0.90140845, 0.90140845,
#         0.90140845, 0.90140845, 0.90140845, 0.90140845, 0.90140845,
#         0.90140845, 0.90140845, 0.90140845, 0.91549296, 0.90140845,
#         0.90140845, 0.88732394]),
#  'split3_test_score': array([0.91549296, 0.94366197, 0.92957746, 0.94366197, 0.91549296,
#         0.92957746, 0.92957746, 0.92957746, 0.91549296, 0.91549296,
#         0.92957746, 0.92957746, 0.91549296, 0.91549296, 0.92957746,
#         0.92957746, 0.91549296, 0.91549296, 0.91549296, 0.91549296,
#         0.91549296, 0.91549296, 0.91549296, 0.91549296, 0.91549296,
#         0.91549296, 0.91549296, 0.91549296, 0.91549296, 0.91549296,
#         0.91549296, 0.91549296]),
#  'split4_test_score': array([0.92957746, 0.92957746, 0.92957746, 0.92957746, 0.92957746,
#         0.92957746, 0.92957746, 0.92957746, 0.92957746, 0.92957746,
#         0.92957746, 0.92957746, 0.92957746, 0.92957746, 0.92957746,
#         0.92957746, 0.92957746, 0.92957746, 0.92957746, 0.92957746,
#         0.92957746, 0.92957746, 0.92957746, 0.92957746, 0.92957746,
#         0.92957746, 0.92957746, 0.92957746, 0.92957746, 0.92957746,
#         0.92957746, 0.92957746]),
#  'split5_test_score': array([0.97183099, 0.97183099, 0.95774648, 0.98591549, 0.97183099,
#         0.97183099, 0.98591549, 0.98591549, 0.97183099, 0.97183099,
#         0.95774648, 0.97183099, 0.97183099, 0.97183099, 0.95774648,
#         0.95774648, 0.97183099, 0.97183099, 0.97183099, 0.97183099,
#         0.95774648, 0.95774648, 0.97183099, 0.97183099, 0.97183099,
#         0.97183099, 0.95774648, 0.97183099, 0.97183099, 0.97183099,
#         0.95774648, 0.95774648]),
#  'mean_test_score': array([0.95305164, 0.9600939 , 0.95539906, 0.96244131, 0.95070423,
#         0.95539906, 0.9600939 , 0.9600939 , 0.94835681, 0.95305164,
#         0.94600939, 0.95539906, 0.94835681, 0.94835681, 0.94600939,
#         0.94600939, 0.95070423, 0.94835681, 0.94600939, 0.94600939,
#         0.94600939, 0.94600939, 0.94600939, 0.94600939, 0.94600939,
#         0.94835681, 0.94131455, 0.94600939, 0.94835681, 0.94835681,
#         0.93896714, 0.94131455]),
#  'std_test_score': array([0.03417892, 0.02747582, 0.02359126, 0.02099594, 0.03123036,
#         0.02624493, 0.02624493, 0.02624493, 0.03513293, 0.03417892,
#         0.02865389, 0.02624493, 0.03513293, 0.03513293, 0.02865389,
#         0.02865389, 0.03227166, 0.03513293, 0.03192833, 0.03192833,
#         0.03393623, 0.03393623, 0.03192833, 0.03192833, 0.03393623,
#         0.03513293, 0.02865389, 0.03192833, 0.03114202, 0.03513293,
#         0.02528246, 0.03393623]),
#  'rank_test_score': array([ 8,  2,  5,  1, 10,  5,  2,  2, 12,  8, 19,  5, 12, 12, 19, 19, 10,
#         12, 19, 19, 19, 19, 19, 19, 19, 12, 30, 19, 12, 12, 32, 30])}

# %% [markdown]
# ##### n_neighbors = 1
# Ukoliko klasifikaciju vršimo na osnovu 1 najbližeg suseda, kakav model dobijamo?
# Naravno, preciznost na trening skupu je **1** (jer je svaka instanca sama sebi najbliži sused).
# Naš model se preprilagodio podacima!

# %%
model = KNeighborsClassifier(n_neighbors=1)
model.fit(X_train, Y_train)
report(model, X_train, Y_train)
report(model, X_test, Y_test, "test")
# Out:
# Classification report for model KNeighborsClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       267
#            1       1.00      1.00      1.00       159
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model KNeighborsClassifier on training data
# ---------------------------------------------------------------------------------
#      B    M
# B  267    0
# M    0  159
# ---------------------------------------------------------------------------------
# Classification report for model KNeighborsClassifier on test data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        90
#            1       0.96      0.94      0.95        53
#
#     accuracy                           0.97       143
#    macro avg       0.96      0.96      0.96       143
# weighted avg       0.96      0.97      0.96       143
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model KNeighborsClassifier on test data
# ---------------------------------------------------------------------------------
#     B   M
# B  88   2
# M   3  50
# ---------------------------------------------------------------------------------

# %% [markdown]
# ##### n_neighbors = veličina trening skupa
# Ako je broj suseda na osnovu kojih vršimo klasifikaciju jednak veličini celog skupa za trening, kakav model dobijamo?
# Svim instancama se dodeljuje brojnija klasa.

# %%
model = KNeighborsClassifier(n_neighbors=X_train.shape[0])
model.fit(X_train, Y_train)
report(model, X_train, Y_train)
report(model, X_test, Y_test, "test")
# Out:
# Classification report for model KNeighborsClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      1.00      0.77       267
#            1       1.00      0.00      0.00       159
#
#     accuracy                           0.63       426
#    macro avg       0.81      0.50      0.39       426
# weighted avg       0.77      0.63      0.48       426
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model KNeighborsClassifier on training data
# ---------------------------------------------------------------------------------
#      B  M
# B  267  0
# M  159  0
# ---------------------------------------------------------------------------------
# Classification report for model KNeighborsClassifier on test data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      1.00      0.77        90
#            1       1.00      0.00      0.00        53
#
#     accuracy                           0.63       143
#    macro avg       0.81      0.50      0.39       143
# weighted avg       0.77      0.63      0.49       143
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model KNeighborsClassifier on test data
# ---------------------------------------------------------------------------------
#     B  M
# B  90  0
# M  53  0
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## Ansambli
# Jedan od najuspešnijih pristupa mašinskom učenju su ansambli (eng. ensemble) - skupovi većeg broja modela koji zajednički donose odluke.
# Ključni ideja je da veći broj modela konstruistan na adekvatan način daje bolju preciznost od samo jednog modela.

# %%
from sklearn.ensemble import BaggingClassifier

baggingKnn = BaggingClassifier(estimator=KNeighborsClassifier(), n_estimators=20)
baggingKnn.fit(X_train, Y_train)

report(baggingKnn, X_train, Y_train)
report(baggingKnn, X_test, Y_test, "test")
# Out:
# Classification report for model BaggingClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       267
#            1       1.00      0.96      0.98       159
#
#     accuracy                           0.98       426
#    macro avg       0.99      0.98      0.98       426
# weighted avg       0.98      0.98      0.98       426
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model BaggingClassifier on training data
# ---------------------------------------------------------------------------------
#      B    M
# B  267    0
# M    7  152
# ---------------------------------------------------------------------------------
# Classification report for model BaggingClassifier on test data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        90
#            1       1.00      0.94      0.97        53
#
#     accuracy                           0.98       143
#    macro avg       0.98      0.97      0.98       143
# weighted avg       0.98      0.98      0.98       143
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model BaggingClassifier on test data
# ---------------------------------------------------------------------------------
#     B   M
# B  90   0
# M   3  50
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## Poređenje dobijenih modela
#
# Napravili smo više modela, sada je pitanje koji od njih najbolje rešava problem klasifikacije. Naravno, ne možemo zaključiti samo na osnovu preciznosti modela.
# Za poređenje koristimo **ROC krivu**.

# %%
from sklearn.metrics import roc_curve, roc_auc_score
models = [knn, estimator.best_estimator_, baggingKnn]
model_names = ['KNN', 'GridSearchCV', 'Ensemble']

plt.figure(figsize=[4,3])

for model, model_name in zip(models, model_names):
    y_pred = model.predict(X_test)
    fpr,tpr, _ = roc_curve(Y_test, y_pred)
    auc = roc_auc_score(Y_test, y_pred)
    lab = model_name + " (auc: " + str(round(auc, 2)) + ")"
    plt.plot(fpr, tpr, label=lab)

plt.plot([0, 1], [0, 1], label='Random (auc: 0.5)', color='red')
plt.title("Poređenje modela")
plt.legend()
plt.show()

# %% [markdown]
# 🤔 Dobili smo iste vrednosti za Ansambl i model za koji smo podesili parametre. Koji izabrati?
# Koje su prednosti/mane ovih modela?

# %% [markdown]
# ### Za vežbu:
# * Pokušajte da poboljšate model finijim podešavanjem parametara
# * Uporediti dobijene modele sa modelima zasnovanim na Stablima odlučivanja. Koje su prednosti/mane knn u odnosu na stabla odlučivanja?
